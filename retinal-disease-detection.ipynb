# %%
# !nvidia-smi
# Out:
# Mon Jun  2 18:39:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0             26W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 59.3 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.148 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6362.0/8062.4 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
from ultralytics import YOLO

#loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
results = model.train(data='/kaggle/input/retinal-disease-ds', epochs=100, imgsz=640)
# Out:
# ...
#   1%|          | 40.2k/5.52M [00:00<00:08, 640kB/s]
# ############################################################################################# 100.0%
# Ultralytics 8.3.148 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
Image("/kaggle/working/runs/classify/train/results.png", width=600)

# %%
Image("/kaggle/working/runs/classify/train/confusion_matrix.png", width=600)

# %%
Image("/kaggle/working/runs/classify/train/train_batch0.jpg", width=600)

# %%
Image("/kaggle/working/runs/classify/train/train_batch1.jpg", width=600)

# %%
Image("/kaggle/working/runs/classify/train/train_batch2.jpg", width=600)

# %%
model = YOLO('/kaggle/working/runs/classify/train/weights/best.pt')
results = model("/kaggle/input/retinal-disease-ds/test/2_glaucoma/0009_png.rf.c79421e1989b80beb4ac0e762a4bbb0c.jpg", conf=0.5, save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/input/retinal-disease-ds/test/2_glaucoma/0009_png.rf.c79421e1989b80beb4ac0e762a4bbb0c.jpg: 640x640 2_glaucoma 1.00, 1_normal 0.00, 2_cataract 0.00, 3_retina_disease 0.00, 5.2ms
# Speed: 19.7ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
results = model("/kaggle/input/retinal-disease-ds/test/1_normal/0016_png.rf.1f6dfa3c451f2e12d908a1ce5506c40a.jpg", conf=0.5, save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/input/retinal-disease-ds/test/1_normal/0016_png.rf.1f6dfa3c451f2e12d908a1ce5506c40a.jpg: 640x640 1_normal 0.89, 2_cataract 0.11, 3_retina_disease 0.00, 2_glaucoma 0.00, 5.3ms
# Speed: 10.4ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
results = model("/kaggle/input/retinal-disease-ds/test/2_cataract/0003_png.rf.6718a9c32ec31b8b74f1d7395ed5a536.jpg", conf=0.5, save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/input/retinal-disease-ds/test/2_cataract/0003_png.rf.6718a9c32ec31b8b74f1d7395ed5a536.jpg: 640x640 2_cataract 1.00, 3_retina_disease 0.00, 1_normal 0.00, 2_glaucoma 0.00, 7.0ms
# Speed: 15.0ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
results = model("/kaggle/input/retinal-disease-ds/test/3_retina_disease/0053_png.rf.a2b1d6d31a09ce98e86043890ad331fd.jpg", conf=0.5, save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/input/retinal-disease-ds/test/3_retina_disease/0053_png.rf.a2b1d6d31a09ce98e86043890ad331fd.jpg: 640x640 3_retina_disease 1.00, 1_normal 0.00, 2_cataract 0.00, 2_glaucoma 0.00, 5.5ms
# Speed: 11.5ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict
# <PIL.Image.Image image mode=RGB size=224x224>
